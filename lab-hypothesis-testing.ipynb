# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
df_dragon = df[df["Type 1"]=="Dragon"]["HP"]
df_grass = df[df["Type 1"]=="Grass"]["HP"]

# %%
#Set the hypothesis

#H0: mu_hp dragon > mu_hp grass
#H1: mu_hp dragon < mu_hp grass

#significance level = 0.05

st.ttest_ind(df_dragon,df_grass, alternative='less')
# Out:
# TtestResult(statistic=3.590444254130357, pvalue=0.9997432030849847, df=100.0)

# %% [markdown]
# **Findings** : since the pvalue is higher than the significant level, we accept the hypothesis that Pokemons of type Dragon have on average more HP stats than Grass.

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
import pandas as pd
from scipy.stats import f_oneway

#Set the hypothesis

#H0: legendary_pokemon_stats = non_legendary_pokemon_stats
#H0: legendary_pokemon_stats != non_legendary_pokemon_stats

#Lets choose significance level of 5%
alpha = 0.05

# List of stats columns
stats_columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# Perform ANOVA test for each stat
for stat in stats_columns:
    legendary_pokemon = df[df['Legendary'] == True][stat]
    non_legendary_pokemon = df[df['Legendary'] == False][stat]
    
    # Perform one-way ANOVA test
    f_statistic, p_value = f_oneway(legendary_pokemon, non_legendary_pokemon)
    
    # Print results
    print(f'Stat: {stat}')
    print(f'F-statistic: {f_statistic:.2f}')
    print(f'p-value: {p_value:.4f}')
    if p_value < 0.05:
        print('Result: Reject null hypothesis - Significant difference found')
    else:
        print('Result: Fail to reject null hypothesis - No significant difference found')
    print('-' * 40)
# Out:
# Stat: HP
# F-statistic: 64.58
# p-value: 0.0000
# Result: Reject null hypothesis - Significant difference found
# ----------------------------------------
# Stat: Attack
# F-statistic: 108.10
# p-value: 0.0000
# Result: Reject null hypothesis - Significant difference found
# ----------------------------------------
# Stat: Defense
# F-statistic: 51.57
# p-value: 0.0000
# Result: Reject null hypothesis - Significant difference found
# ----------------------------------------
# Stat: Sp. Atk
# F-statistic: 201.40
# p-value: 0.0000
# Result: Reject null hypothesis - Significant difference found
# ----------------------------------------
# Stat: Sp. Def
# F-statistic: 121.83
# p-value: 0.0000
# Result: Reject null hypothesis - Significant difference found
# ----------------------------------------
# Stat: Speed
# F-statistic: 95.36
# p-value: 0.0000
# Result: Reject null hypothesis - Significant difference found
# ----------------------------------------

# %% [markdown]
# Based on the p-values obtained, which is less than 0.05, we reject the null hypothesis and conclude that there is a statistically significant difference in the mean stats between Legendary and Non-Legendary Pokémon.

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 37)
# - Hospital coordinates (-122, 34)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
# Let's calculate the distance for each school and each hospital : 

# distances to school and hospital
df['distance_to_school'] = ((df['longitude'] - school_coords[0]) ** 2 + (df['latitude'] - school_coords[1]) ** 2) ** 0.5
df['distance_to_hospital'] = ((df['longitude'] - hospital_coords[0]) ** 2 + (df['latitude'] - hospital_coords[1]) ** 2) ** 0.5

# %%
# Divide dataset into houses close and far from either a hospital or school

close_houses = df[(df['distance_to_school'] < threshold_distance) | (df['distance_to_hospital'] < threshold_distance)]
far_houses = df[(df['distance_to_school'] >= threshold_distance) & (df['distance_to_hospital'] >= threshold_distance)]

# %%
# Display the dataframe with houses close from either a hospital or school : 
display(close_houses)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4523    -118.05     36.64                34.0       2090.0           478.0
# 5596    -118.18     37.35                16.0       3806.0           794.0
# 5597    -118.18     36.63                23.0       2311.0           487.0
# 6776    -118.30     37.17                22.0       3480.0           673.0
# 6904    -118.31     36.94                35.0       2563.0           530.0
#
#       population  households  median_income  median_house_value  \
# 4523       896.0       426.0         2.0357             74200.0
# 5596      1501.0       714.0         2.1212            108300.0
# 5597      1019.0       384.0         2.2574            104700.0
# 6776      1541.0       636.0         2.7500             94500.0
# 6904       861.0       371.0         2.3250             80600.0
#
#       distance_to_school  distance_to_hospital
# 4523            0.363456              4.751010
# ...

# %%
# Display the dataframe with houses far from either a hospital or school : 
display(far_houses)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# Choose the propper test and, with 5% significance, comment your findings.

from scipy.stats import mannwhitneyu

# Let's perform Mann-Whitney U test
statistic, p_value = mannwhitneyu(close_houses['median_house_value'], far_houses['median_house_value'])

alpha = 0.05

print("Mann-Whitney U test p-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis. There is sufficient evidence to suggest that houses close to either a school or a hospital are more expensive.")
else:
    print("Fail to reject the null hypothesis. There is not enough evidence to suggest that houses close to either a school or a hospital are more expensive.")
# Out:
# Mann-Whitney U test p-value: 0.005835992784005986
# Reject the null hypothesis. There is sufficient evidence to suggest that houses close to either a school or a hospital are more expensive.
